# %% [markdown]
# #### NAME : KRISHNA GOHIL
#
# # Data Science & Business Analytics Task-6
#
# ### TOPIC: Prediction using Decision Tree Algorithm
#
# ### TASK :Create the Decision Tree classifier and visualize it graphically.

# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %% [markdown]
# ### Loading the dataset

# %%
data=pd.read_csv("Downloads/iris.csv")

# %% [markdown]
# ### DATA EXPLORATION

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### PREPROCESSING THE DATASET

# %%
data=data.drop('Id',axis=1) #ID NOT REQUIRED

# %%
x=data.iloc[:,:-1].values

# %%
y=data.iloc[:,4].values

# %% [markdown]
# ### APPLYING DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import graphviz

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
classify=tree.DecisionTreeClassifier(random_state=25)
classify=classify.fit(X_train,y_train)

# %%
y_pred=classify.predict(X_test)

# %% [markdown]
# ### ACCURACY

# %%
print('Accuracy: {0:.4f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy: 0.9556

# %% [markdown]
# ### Visualising Decision Tree Classifier Graphically

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data=export_graphviz(classify,out_file=None,filled=True,proportion=True,
                        feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
                        class_names=['Setosa','Versicolor','Virginica'])

# %%
graph=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# # THANKYOU !
